# %%
pip install tensorflow
# Out:
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=1e1f538f5284e85a6c0c68af2babc8284f3914425dab50009a0f4e6b1e31dfac
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np

# %%
filename = 'media//dog1.jpg'

# %% [markdown]
# # First method to load an image

# %%
from IPython.display import Image
Image(filename = 'media//dog1.jpg', width=224, height=224) #most of image are trained on 224x224 size

# %% [markdown]
# # Second method to load an image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size=(244,244))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# # Third method to load an image

# %%
import cv2

# %%
imgg=cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg=cv2.resize(imgg, (224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Forth method to load an image

# %%
from PIL import Image

# %%
im = Image.open(filename)

# %%
im=im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Loading deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() #deep learning model weights - pre-trained

# %%
## Creating a model
## Training a model
## Test or validate
## Predict

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()
# Out:
# ...
# 14536120/14536120 [==============================] - 1s 0us/step

# %%
anyone=tf.keras.applications.

# %% [markdown]
# # Pre-processing of the image

# %%
filename='media//shark1.jpg'

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size=(224,224))

# %%
plt.imshow(img)

# %%
resized_img=image.img_to_array(img)
final_image=np.expand_dims(resized_img,axis=0) #need forth dimention
final_image=tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 287ms/step

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01484850', 'great_white_shark', 0.9847193), ('n01491361', 'tiger_shark', 0.011867666), ('n02514041', 'barracouta', 0.0008019767), ('n01494475', 'hammerhead', 0.00079455046), ('n02074367', 'dugong', 0.00054850307)]]

# %%
plt.imshow(img)

# %%
predictions = mobile.predict(final_image)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
results=imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n01484850', 'great_white_shark', 0.9710689), ('n01491361', 'tiger_shark', 0.00320599), ('n01494475', 'hammerhead', 0.00096811773), ('n02514041', 'barracouta', 0.0005951077), ('n04347754', 'submarine', 0.0005047599)]]
